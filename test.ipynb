# %%
# !python detect.py --weights runs/train/exp21/weights/best.pt --kpt-label --source final_dataset/images/test --conf-thres 0.030 --iou-thres 0.30 --save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.03, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.3, kpt_label=True, line_thickness=3, name='exp', nosave=False, project='runs/detect', save_bin=False, save_conf=False, save_crop=False, save_txt=True, save_txt_tidl=False, source='final_dataset/images/test', update=False, view_img=False, weights=['runs/train/exp21/weights/best.pt'])
# YOLOv5 � a05e48d torch 2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 9987.25MB)
#
# Fusing layers...
# /home/erichu/miniconda3/envs/xraybone/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 494 layers, 79878368 parameters, 0 gradients, 100.9 GFLOPS
# ...
